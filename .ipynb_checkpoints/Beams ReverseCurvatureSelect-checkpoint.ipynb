# %%
import pandas as pd
import numpy as np
import os
import lib.csiapi as csiapi
import lib.util as util

# %load_ext autoreload
# %autoreload 2

ETABSObject, SapModel = csiapi.get_active_etabs_object()
# create folder for temporary csv files
csv_folder_path = os.getcwd() + r'\csv'
if not os.path.exists(csv_folder_path):
    os.makedirs(csv_folder_path)
# Out:
# Succesfully created helper object
# Succesfully created SapModel

# %%
SapModel.Analyze.RunAnalysis()


# SapModel.DatabaseTables.SetLoadCombinationsSelectedForDisplay("")
# SapModel.DatabaseTables.SetLoadCasesSelectedForDisplay("Dead")
# Out:
# 0

# %%
beam_table_dead = csiapi.get_table_display(SapModel, "Element Forces - Beams")

# %%
beam_table_dead
# Out:
#             Story  Beam  Unique Name Output Case  Case Type  Step Type  \
# 0          Story5  B277          298        Dead  LinStatic        NaN
# 1          Story5  B277          298        Dead  LinStatic        NaN
# 2          Story5  B277          298        Dead  LinStatic        NaN
# 3          Story5  B277          298        Dead  LinStatic        NaN
# 4          Story5  B277          298        Dead  LinStatic        NaN
# ...           ...   ...          ...         ...        ...        ...
# 8302  Lantai Atap  B226         1089        Dead  LinStatic        NaN
# 8303  Lantai Atap  B226         1089        Dead  LinStatic        NaN
# 8304  Lantai Atap  B226         1089        Dead  LinStatic        NaN
# 8305  Lantai Atap  B226         1089        Dead  LinStatic        NaN
# 8306  Lantai Atap  B226         1089        Dead  LinStatic        NaN
#
#       Step Number  Step Label  Station        P       V2      V3       T  \
# 0             NaN         NaN   0.3500 -27.8235  -9.8510 -0.0580 -0.0113
# 1             NaN         NaN   0.8318 -27.8235  -8.1480 -0.0580 -0.0113
# 2             NaN         NaN   1.3136 -27.8235  -6.4451 -0.0580 -0.0113
# 3             NaN         NaN   1.7955 -27.8235  -4.7421 -0.0580 -0.0113
# 4             NaN         NaN   2.2773 -27.8235  -3.0391 -0.0580 -0.0113
# ...           ...         ...      ...      ...      ...     ...     ...
# 8302          NaN         NaN   7.0000  -7.7160  33.3471  0.0141 -0.7100
# 8303          NaN         NaN   7.5000  -7.7160  44.5808  0.0141 -0.7100
# 8304          NaN         NaN   8.0000  -7.7160  53.3117  0.0141 -0.7100
# 8305          NaN         NaN   8.5000  -7.7160  59.5400  0.0141 -0.7100
# 8306          NaN         NaN   9.0000  -7.7160  63.2655  0.0141 -0.7100
#
#           M2       M3 Element  Elem Station Location
# 0    -0.1828  -8.0551     298        0.3500      NaN
# 1    -0.1549  -3.7190     298        0.8318      NaN
# 2    -0.1269  -0.2034     298        1.3136      NaN
# 3    -0.0990   2.4917     298        1.7955      NaN
# 4    -0.0710   4.3662     298        2.2773      NaN
# ...      ...      ...     ...           ...      ...
# 8302 -0.0125  18.0648  1089-2        2.5000      NaN
# 8303 -0.0195  -1.5215  1089-2        3.0000      NaN
# 8304 -0.0266 -26.0989  1089-2        3.5000      NaN
# 8305 -0.0336 -54.4161  1089-2        4.0000      NaN
# 8306 -0.0407 -85.2217  1089-2        4.5000      NaN
#
# [8307 rows x 18 columns]

# %%
unique_name = beam_table_dead['Unique Name'].drop_duplicates()

# %%
weird_beams = []
for i in unique_name:
    idx = beam_table_dead['Unique Name'] == i
    temp_table = beam_table_dead["M3"].loc[idx]
    if temp_table.iloc[-1] * temp_table.iloc[0] < 0:
        weird_beams.append(i)
        SapModel.FrameObj.SetSelected(str(i),True)

# %%
weird_beams
# Out:
# [529,
#  531,
#  532,
#  534,
#  535,
#  537,
#  538,
#  540,
#  542,
#  543,
#  544,
#  545,
#  547,
#  548,
#  550,
#  552,
#  553,
#  555,
#  556,
#  559,
#  578,
#  579,
#  580,
#  505,
#  507,
#  510,
#  514,
#  516,
#  518,
#  519,
#  521,
#  522,
#  523,
#  524,
#  577,
#  436,
#  570,
#  790,
#  791,
#  793,
#  821,
#  823,
#  824,
#  825,
#  826,
#  827,
#  828,
#  829,
#  830,
#  832,
#  833,
#  835,
#  836,
#  837,
#  838,
#  840,
#  841,
#  847,
#  848,
#  849,
#  850,
#  858,
#  859,
#  860,
#  861,
#  862,
#  863,
#  864,
#  865,
#  866,
#  867,
#  868,
#  869,
#  870,
#  871,
#  872,
#  873,
#  874,
#  875,
#  876,
#  877,
#  878,
#  879,
#  880,
#  881,
#  882,
#  883,
#  884,
#  885,
#  886,
#  887,
#  888,
#  889,
#  890,
#  891,
#  892,
#  893,
#  894,
#  895,
#  896,
#  897,
#  929,
#  932,
#  933,
#  935,
#  938,
#  939,
#  941,
#  948,
#  818,
#  820,
#  851,
#  852,
#  854,
#  855,
#  857,
#  926,
#  927,
#  934,
#  940,
#  947,
#  955,
#  956,
#  965,
#  970,
#  318,
#  319,
#  321,
#  322,
#  323,
#  325,
#  326,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  333,
#  334,
#  335,
#  336,
#  337,
#  393,
#  397,
#  398,
#  403,
#  407,
#  412,
#  416,
#  417,
#  422,
#  426,
#  568,
#  569,
#  269,
#  270,
#  274,
#  275,
#  279,
#  280,
#  284,
#  285,
#  153,
#  161,
#  155,
#  154,
#  156,
#  663,
#  159,
#  82,
#  157,
#  89,
#  108,
#  134,
#  73,
#  166,
#  77,
#  168,
#  680,
#  165,
#  164,
#  170,
#  163,
#  685,
#  162,
#  181,
#  182,
#  183,
#  187,
#  184,
#  185,
#  186,
#  189,
#  990,
#  991,
#  993,
#  994,
#  152,
#  995,
#  996,
#  997,
#  998,
#  999,
#  1000,
#  1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1007,
#  1008,
#  1013,
#  1014,
#  1015,
#  1020,
#  1021,
#  1024,
#  1025,
#  1026,
#  1028,
#  1029,
#  1019,
#  1031,
#  1032,
#  1033,
#  1034,
#  1035,
#  1036,
#  1037,
#  1038,
#  1039,
#  1040,
#  1041,
#  1042,
#  1044,
#  1046,
#  1048,
#  1043,
#  1091]
